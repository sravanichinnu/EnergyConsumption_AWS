# %% [markdown]
# ## Data Integration & Feature Engineering (AWS Glue)
#
# Raw PJME hourly energy data is ingested and transformed using an AWS Glue Pandas ETL job.
#
# The full production ETL logic is implemented in : 'glue/pjme_pandas_etl_job.py'
#
# This notebook focuses on explaining the transformation logic and downstream usage, not re-running the Glue job locally.

# %%
import pandas as pandas

df = pd.read_parquet(
    "s3://energy-consumption-forecasting-project/processed/pandas/pjme_energy_features.paruet"
)

df.head()

# %% [markdown]
# This dataset contains lag features, rolling statistics, and calendar features used for downstream time-series forecasting.
